# %%
# %load_ext autoreload
# %autoreload all

# %%
from pymf6.mf6 import MF6

# %%
mf6 = MF6(sim_path='mf6')

# %%
gwt = mf6.models['gwt6']

# %%
t = gwt['gwt_cat_ex_1d']

# %%
t.solution_id
# Out:
# np.int32(2)

# %%
mf6.vars['SLN_2/X']
# Out:
# array([1., 1., 1., ..., 1., 1., 1.], shape=(38,))

# %%
for _ in mf6.model_loop():
    pass
