# %%
# %load_ext autoreload
# %autoreload all

# %%
import typer

# %%
dir(typer.Typer)
# Out:
# ['__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__firstlineno__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__static_attributes__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_info_val_str',
#  'add_typer',
#  'callback',
#  'command']

# %%
from rtmf6.config import Config
from rtmf6.preprocessing.create_inputs import make_inputs
# Out:
# <frozen importlib._bootstrap>:491: DeprecationWarning: builtin type SwigPyPacked has no __module__ attribute
# <frozen importlib._bootstrap>:491: DeprecationWarning: builtin type SwigPyObject has no __module__ attribute

# %%
project_toml = ('rtmf6/rtmf6.toml')

# %%
config = Config(project_toml)

# %%
make_inputs(config)

# %%
make_inputs(config)
# Out:
# [0.0005982144915017591]
# [0]
# xxx
# {0: rec.array([((0, 0, 0), 1, 0, 0)],
#           dtype=[('cellid', 'O'), ('q', '<i8'), ('concentration', '<i8'), ('rtmf6_sol_number', '<i8')])}
# [0.0005982144915017591]

# %%
import numpy as np

# %%
a = np.array(
    [((0, 0, 0), 1, 0, 0)],
    dtype=[('cellid', 'O'), ('q', '<i8'), ('concentration', '<i8'), ('rtmf6_sol_number', '<i8')]
)

# %%
a
# Out:
# array([((0, 0, 0), 1, 0, 0)],
#       dtype=[('cellid', 'O'), ('q', '<i8'), ('concentration', '<i8'), ('rtmf6_sol_number', '<i8')])

# %%
descr
# Out:
# [('cellid', '|O'),
#  ('q', '<i8'),
#  ('concentration', '<i8'),
#  ('rtmf6_sol_number', '<i8')]

# %%
descr = a.dtype.descr
new_descr = []
for name, dtype in descr:
    if name == 'concentration':
        new_descr.append((name, np.float64))
    else:
        new_descr.append((name, dtype))
a.astype(np.dtype(new_descr))
# Out:
# array([((0, 0, 0), 1, 0., 0)],
#       dtype=[('cellid', 'O'), ('q', '<i8'), ('concentration', '<f8'), ('rtmf6_sol_number', '<i8')])

# %%
# Out:
# array([((0, 0, 0), 1, 0., 0)],
#       dtype=[('cellid', 'O'), ('q', '<i8'), ('concentration', '<f8'), ('rtmf6_sol_number', '<i8')])

# %%
descr[2]
# Out:
# ('concentration', '<i8')

# %%
dt[0][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[39], line 1
# ----> 1 dt[0][0]
#
# KeyError: 'There are no fields in dtype object.'

# %%
dt['concentration'] = np.dtype('float64')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 dt['concentration'] = np.dtype('float64')
#
# TypeError: 'numpy.dtypes.VoidDType' object does not support item assignment

# %%
dt['concentration'][0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 dt['concentration'][0]
#
# KeyError: 'There are no fields in dtype int64.'

# %%
dt = dt.descr # this is now a modifiable list, can't modify numpy.dtype
# change the type of the first col:
dt[0] = (dt[0][0], 'float64')
dt = numpy.dtype(dt)
# data = numpy.array(data, dtype=dt) # option 1
data = data.astype(dt)
