# %% [markdown]
# # Example Workflow
#
# This notebook demonstrates a basic rtmf6 workflow for reactive transport modeling.

# %% [markdown]
# ## Setup
#
# First, let's import the necessary modules:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Basic Example
#
# Here's a simple demonstration of plotting capabilities:

# %%
# Create sample data
x = np.linspace(0, 10, 100)
y = np.sin(x) * np.exp(-x / 10)

# Create plot
fig, ax = plt.subplots(figsize=(8, 4))
ax.plot(x, y, 'b-', linewidth=2)
ax.set_xlabel('Distance (m)')
ax.set_ylabel('Concentration (mol/L)')
ax.set_title('Example: Concentration Profile')
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Next Steps
#
# For real simulations, you would:
#
# 1. Set up your MODFLOW 6 model
# 2. Configure the PHREEQC reactions
# 3. Run the coupled simulation
# 4. Analyze the results
#
# See the API documentation for detailed information on each module.
